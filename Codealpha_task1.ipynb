# %% [markdown]
# <a href="https://colab.research.google.com/github/poojasrigurusamy-art/poojasri-G/blob/main/Codealpha_task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scapy.all import sniff

def packet_callback(packet):
    print("\n==============================")

    # Source and Destination IP
    if packet.haslayer("IP"):
        print("Source IP      :", packet["IP"].src)
        print("Destination IP :", packet["IP"].dst)
        print("Protocol       :", packet["IP"].proto)

    # Payload
    if packet.haslayer("Raw"):
        try:
            print("Payload        :", packet["Raw"].load.decode(errors="ignore"))
        except:
            print("Payload        : Unable to decode")

# Capture 10 packets
print("Capturing packets...")
sniff(prn=packet_callback, count=10)

print("\n Packet capture completed.")
# Out:
# Capturing packets...
#
# ...
# Source IP      : 172.28.0.12
# Destination IP : 172.28.0.1
# Protocol       : 6
# Payload        : ~{"header": {"msg_id": "f42d626a-d162b3e38130393b2dbcec14_2106_75", "msg_type": "stream", "username": "username", "session": "f42d626a-d162b3e38130393b2dbcec14", "date": "2026-07-19T08:16:08.707045Z", "version": "5.3"}, "msg_id": "f42d626a-d162b3e38130393b2dbcec14_2106_75", "msg_type": "stream", "parent_header": {"msg_id": "989a7bdf-4d80-419b-9f74-1b0e13ba4581", "username": "username", "session": "875884c0-1ec5-4368-d7a4-ef7fa353823a", "msg_type": "execute_request", "version": "5.0", "date": "2026-07-19T08:16:07.794045Z"}, "metadata": {}, "content": {"name": "stdout", "text": "Capturing packets...\n"}, "buffers": [], "channel": "iopub"}
#
# ...
# Source IP      : 172.28.0.1
# Destination IP : 172.28.0.12
# Protocol       : 6
#
# ...
# Source IP      : 172.28.0.12
# Destination IP : 172.28.0.1
# Protocol       : 6
# ...

# %%
# !pip install scapy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 44.7 MB/s eta 0:00:00
# ...
