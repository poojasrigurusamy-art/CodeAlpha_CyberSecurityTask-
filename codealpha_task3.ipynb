# %% [markdown]
# <a href="https://colab.research.google.com/github/poojasrigurusamy-art/poojasri-G/blob/main/codealpha_task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Network Intrusion Detection System
# Using Machine Learning (Decision Tree)

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score


# Sample network traffic data
# Features: [Packets, Connection_Time, Failed_Login]

X = [
    [100, 10, 0],
    [150, 15, 1],
    [200, 20, 0],
    [500, 60, 10],
    [700, 80, 15],
    [50, 5, 0],
    [600, 70, 12],
    [120, 12, 1]
]

# Labels
# 0 = Normal Traffic
# 1 = Intrusion

y = [0, 0, 0, 1, 1, 0, 1, 0]


# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)


# Create model
model = DecisionTreeClassifier()

# Train model
model.fit(X_train, y_train)


# Test model
prediction = model.predict(X_test)

accuracy = accuracy_score(y_test, prediction)

print("Network Intrusion Detection System")
print("----------------------------------")

print("Accuracy:", accuracy)


# New network traffic check

new_data = [[800, 90, 20]]

result = model.predict(new_data)

if result[0] == 1:
    print("Alert: Intrusion Detected!")
else:
    print("Network Traffic is Normal")
# Out:
# Network Intrusion Detection System
# ----------------------------------
# Accuracy: 1.0
# Alert: Intrusion Detected!
